# %% [markdown]
# # Art Style Explorer Demo
#
# This notebook demonstrates the workflow of the Art Style Explorer project, which analyzes artwork images to find stylistically similar artists and artworks.

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: numpy==1.24.3 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: scipy==1.10.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (1.10.1)
# Requirement already satisfied: matplotlib==3.7.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: opencv-python==4.8.0.74 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 4)) (4.8.0.74)
# Requirement already satisfied: pillow==9.5.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 5)) (9.5.0)
# Requirement already satisfied: scikit-image==0.20.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: scikit-learn==1.2.2 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: torch==2.0.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: torchvision==0.15.2 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 9)) (0.15.2)
# Requirement already satisfied: pandas==2.0.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: tqdm==4.65.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 11)) (4.65.0)
# Requirement already satisfied: jupyter==1.0.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: pytest==7.3.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from -r ../requirements.txt (line 13)) (7.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from matplotlib==3.7.1->-r ../requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from matplotlib==3.7.1->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from matplotlib==3.7.1->-r ../requirements.txt (line 3)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from matplotlib==3.7.1->-r ../requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from matplotlib==3.7.1->-r ../requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from matplotlib==3.7.1->-r ../requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from matplotlib==3.7.1->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: networkx>=2.8 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from scikit-image==0.20.0->-r ../requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: imageio>=2.4.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from scikit-image==0.20.0->-r ../requirements.txt (line 6)) (2.37.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from scikit-image==0.20.0->-r ../requirements.txt (line 6)) (2025.2.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from scikit-image==0.20.0->-r ../requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: lazy_loader>=0.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from scikit-image==0.20.0->-r ../requirements.txt (line 6)) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from scikit-learn==1.2.2->-r ../requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from scikit-learn==1.2.2->-r ../requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from torch==2.0.1->-r ../requirements.txt (line 8)) (3.17.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from torch==2.0.1->-r ../requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from torch==2.0.1->-r ../requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from torch==2.0.1->-r ../requirements.txt (line 8)) (3.1.5)
# Requirement already satisfied: requests in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from torchvision==0.15.2->-r ../requirements.txt (line 9)) (2.32.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from pandas==2.0.1->-r ../requirements.txt (line 10)) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from pandas==2.0.1->-r ../requirements.txt (line 10)) (2025.1)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 12)) (7.3.2)
# Requirement already satisfied: qtconsole in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 12)) (5.6.1)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 12)) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 12)) (7.16.6)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 12)) (6.29.5)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter==1.0.0->-r ../requirements.txt (line 12)) (8.1.5)
# Requirement already satisfied: iniconfig in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from pytest==7.3.1->-r ../requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from pytest==7.3.1->-r ../requirements.txt (line 13)) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from pytest==7.3.1->-r ../requirements.txt (line 13)) (1.2.2)
# Requirement already satisfied: tomli>=1.0.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from pytest==7.3.1->-r ../requirements.txt (line 13)) (2.2.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.1->-r ../requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (8.32.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->-r ../requirements.txt (line 12)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->-r ../requirements.txt (line 12)) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jinja2->torch==2.0.1->-r ../requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->-r ../requirements.txt (line 12)) (3.0.50)
# Requirement already satisfied: pygments in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.19.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (4.3.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.4.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from requests->torchvision==0.15.2->-r ../requirements.txt (line 9)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from requests->torchvision==0.15.2->-r ../requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from requests->torchvision==0.15.2->-r ../requirements.txt (line 9)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from requests->torchvision==0.15.2->-r ../requirements.txt (line 9)) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from sympy->torch==2.0.1->-r ../requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (4.9.0)
# Requirement already satisfied: stack_data in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (4.3.6)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (4.8.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyterlab<4.4,>=4.3.4->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyterlab<4.4,>=4.3.4->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyterlab<4.4,>=4.3.4->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.2.5)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyterlab<4.4,>=4.3.4->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (75.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.21.1)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.6)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.23.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->-r ../requirements.txt (line 12)) (0.2.3)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/cs224n-cpu/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r ../requirements.txt (line 12)) (2.9.0.20241206)

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
from PIL import Image

# Add parent directory to path
sys.path.append('..')

# %% [markdown]
# ## 1. Setup
#
# First, let's import the necessary modules from our project.

# %%
from src.preprocessing.edge_detection import process_artwork, detect_contours, analyze_contours
from src.preprocessing.normalization import standardize_artwork
from src.features.line_features import extract_line_features, extract_hough_lines, visualize_lines
from src.features.composition import extract_composition_features
from src.utils.visualization import (
    visualize_edges,
    visualize_line_features,
    visualize_composition_features,
    visualize_similar_artworks
)

# %% [markdown]
# ## 2. Load and Process an Artwork
#
# Now, let's load an artwork image and process it.

# %%
# Path to an artwork image
image_path = '../sample_data/starry_night.jpg'  # Replace with your image path

# Process the artwork to extract line work
preprocessed, edges = process_artwork(
    image_path, 
    target_size=(512, 512),
    edge_method='canny'
)

# Visualize the original image and edge detection
fig = visualize_edges(preprocessed, edges)
plt.show()
# Out:
# [ WARN:0@122.287] global loadsave.cpp:248 findDecoder imread_('../sample_data/starry_night.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 image_path = '../sample_data/starry_night.jpg'  # Replace with your image path
#       4 # Process the artwork to extract line work
# ----> 5 preprocessed, edges = process_artwork(
#       6     image_path,
#       7     target_size=(512, 512),
#       8     edge_method='canny'
#       9 )
#      11 # Visualize the original image and edge detection
#      12 fig = visualize_edges(preprocessed, edges)
#
# File ~/GitHub/art-style-explorer/notebooks/../src/preprocessing/edge_detection.py:160, in process_artwork(image_path, target_size, edge_method, low_threshold, high_threshold, thin_method)
#     145 """
#     146 Process artwork to extract line work
#     147
#    (...)
#     157     Tuple of (preprocessed image, line work)
#     158 """
#     159 # Read and preprocess the image
# --> 160 original = read_image(image_path)
#     161 preprocessed = preprocess_image(original, target_size)
#     163 # Extract edges
#
# File ~/GitHub/art-style-explorer/notebooks/../src/preprocessing/edge_detection.py:18, in read_image(image_path)
#      16 img = cv2.imread(image_path)
#      17 if img is None:
# ---> 18     raise FileNotFoundError(f"Image not found at {image_path}")
#      19 return img
#
# FileNotFoundError: Image not found at ../sample_data/starry_night.jpg

# %% [markdown]
# ## 3. Extract Line Features
#
# Let's extract and visualize line features from the artwork.

# %%
# Detect contours in the edge image
contours = detect_contours(edges)

# Extract Hough lines
lines = extract_hough_lines(edges)

# Visualize the lines
line_fig = visualize_line_features(preprocessed, lines)
plt.show()

# Extract line features
line_features = extract_line_features(edges, contours)

# Print some key line features
print(f"Number of lines: {line_features['line_count']}")
print(f"Mean line length: {line_features['mean_length']:.2f}")
print(f"Horizontal ratio: {line_features['horizontal_ratio']:.2f}")
print(f"Vertical ratio: {line_features['vertical_ratio']:.2f}")
print(f"Diagonal ratio: {line_features['diagonal_ratio']:.2f}")
print(f"Mean curvature: {line_features['mean_curvature']:.2f}")
print(f"Number of intersections: {line_features['intersection_count']}")
print(f"Number of contours: {line_features['contour_count']}")
print(f"Average complexity: {line_features['avg_complexity']:.2f}")

# %% [markdown]
# ## 4. Extract Composition Features
#
# Now, let's extract and visualize composition features.

# %%
# Extract composition features
composition_features = extract_composition_features(preprocessed)

# Visualize composition features
comp_fig = visualize_composition_features(preprocessed, composition_features)
plt.show()

# Print some key composition features
print(f"Rule of thirds adherence: {composition_features['thirds_adherence']:.2f}")
print(f"Horizontal symmetry: {composition_features['horizontal_symmetry']:.2f}")
print(f"Vertical symmetry: {composition_features['vertical_symmetry']:.2f}")
print(f"Overall symmetry: {composition_features['overall_symmetry']:.2f}")
print(f"Golden ratio adherence: {composition_features['golden_ratio_adherence']:.2f}")
print(f"Horizontal balance: {composition_features['horizontal_balance']:.2f}")
print(f"Vertical balance: {composition_features['vertical_balance']:.2f}")
print(f"Radial balance: {composition_features['radial_balance']:.2f}")

# %% [markdown]
# ## 5. Create a Feature Vector
#
# Let's combine the line and composition features into a single feature vector.

# %%
# Define a function to convert features to a vector (same as in main.py)
def get_features_vector(line_features, composition_features):
    # Select numerical features from line_features
    line_values = [
        line_features['line_count'],
        line_features['mean_length'],
        line_features['std_length'],
        line_features['max_length'],
        line_features['min_length'],
        line_features['horizontal_ratio'],
        line_features['vertical_ratio'],
        line_features['diagonal_ratio'],
        line_features['mean_curvature'],
        line_features['std_curvature'],
        line_features['max_curvature'],
        line_features['min_curvature'],
        line_features['intersection_count'],
        line_features['contour_count'],
        line_features['avg_complexity']
    ]
    
    # Add orientation histogram
    line_values.extend(line_features['orientation_histogram'])
    
    # Select numerical features from composition_features
    comp_values = [
        composition_features['horizontal_line_energy'],
        composition_features['vertical_line_energy'],
        composition_features['intersection_energy'],
        composition_features['thirds_adherence'],
        composition_features['horizontal_symmetry'],
        composition_features['vertical_symmetry'],
        composition_features['diagonal_symmetry'],
        composition_features['overall_symmetry'],
        composition_features['golden_horizontal_energy'],
        composition_features['golden_vertical_energy'],
        composition_features['golden_spiral_energy'],
        composition_features['golden_ratio_adherence'],
        composition_features['horizontal_balance'],
        composition_features['vertical_balance'],
        composition_features['radial_balance']
    ]
    
    # Combine line and composition features
    features_vector = np.array(line_values + comp_values, dtype=np.float32)
    
    return features_vector

# Create the feature vector
features_vector = get_features_vector(line_features, composition_features)

# Print the shape of the feature vector
print(f"Feature vector shape: {features_vector.shape}")

# Plot the feature vector as a bar chart
plt.figure(figsize=(15, 5))
plt.bar(range(len(features_vector)), features_vector)
plt.title('Feature Vector')
plt.xlabel('Feature Index')
plt.ylabel('Feature Value')
plt.show()

# %% [markdown]
# ## 6. Load the Neural Network Model
#
# Now, let's load a pre-trained neural network model for art style analysis.

# %%
# Import the model
from src.model.network import ArtStyleNetwork
from src.model.training import load_model

# Initialize the model
model = ArtStyleNetwork(
    input_channels=1,  # Grayscale images
    line_feature_dim=128,
    comp_feature_dim=64,
    embedding_dim=256,
    num_classes=100,  # Placeholder for number of artist classes
    comp_input_dim=len(features_vector)  # Use actual feature vector length
)

# Use CPU for now (replace with GPU if available)
device = 'cpu'

# In a real scenario, you would load a pre-trained model like this:
# model = load_model(model, 'path/to/checkpoint.pth', device=device)

# For demonstration, we'll just use the uninitialized model
model = model.to(device)

# %% [markdown]
# ## 7. Extract Embedding
#
# Let's extract an art style embedding from our image using the model.

# %%
# Convert the image and features to torch tensors
image_tensor = torch.tensor(preprocessed, dtype=torch.float32).unsqueeze(0).unsqueeze(0) / 255.0  # Normalize
features_tensor = torch.tensor(features_vector, dtype=torch.float32).unsqueeze(0)

# Move to device
image_tensor = image_tensor.to(device)
features_tensor = features_tensor.to(device)

# Extract embedding
with torch.no_grad():
    embedding = model.extract_features(image_tensor, features_tensor)

# Print the embedding shape
print(f"Embedding shape: {embedding.shape}")

# Plot the embedding as a bar chart
plt.figure(figsize=(15, 5))
plt.bar(range(embedding.shape[1]), embedding.cpu().numpy()[0])
plt.title('Art Style Embedding')
plt.xlabel('Dimension')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ## 8. Find Similar Artworks (Simulation)
#
# Since we don't have a database of artworks in this demo, let's simulate finding similar artworks by generating random embeddings.

# %%
# Import functions for finding similar artworks
import torch.nn.functional as F

# Simulate a database of artworks
num_database_artworks = 100
embedding_dim = embedding.shape[1]

# Generate random embeddings for the database
# In a real application, these would be extracted from actual artworks
database_embeddings = torch.randn(num_database_artworks, embedding_dim)

# Normalize the embeddings
database_embeddings = F.normalize(database_embeddings, p=2, dim=1)

# Simulate artist names and artwork titles
artists = [f"Artist {i % 20 + 1}" for i in range(num_database_artworks)]
titles = [f"Artwork {i + 1}" for i in range(num_database_artworks)]

# Calculate cosine similarity between the query embedding and database embeddings
similarities = F.cosine_similarity(embedding, database_embeddings)

# Find the top-5 most similar artworks
top_k = 5
top_indices = torch.topk(similarities, k=top_k).indices.cpu().numpy()
top_similarities = similarities[top_indices].cpu().numpy()

# Print the results
print("Top 5 similar artworks:")
for i, (idx, sim) in enumerate(zip(top_indices, top_similarities)):
    print(f"{i+1}. {artists[idx]} - {titles[idx]} (Similarity: {sim:.4f})")

# %% [markdown]
# ## 9. Visualize Similar Artworks (Simulation)
#
# Let's simulate visualizing the query image and similar artworks.

# %%
# Load the original query image
query_image = cv2.imread(image_path)
query_image = cv2.cvtColor(query_image, cv2.COLOR_BGR2RGB)

# Generate random similar images for demonstration
# In a real application, these would be actual similar artworks
similar_images = [np.random.randint(0, 256, (512, 512, 3), dtype=np.uint8) for _ in range(top_k)]

# Visualize the query image and similar artworks
similar_fig = visualize_similar_artworks(
    query_image, 
    similar_images, 
    [artists[idx] for idx in top_indices], 
    [titles[idx] for idx in top_indices], 
    top_similarities
)

plt.show()

# %% [markdown]
# ## 10. Complete Workflow
#
# In a real application, you would:
#
# 1. Collect a large dataset of artwork images with associated metadata
# 2. Train the neural network model using the training script
# 3. Extract features from all artworks in the database
# 4. Use the main application to analyze new artwork images and find similar styles
#
# The command-line interface makes it easy to use the application:

# %%
print("Training command example:")
print("python train.py \
    --data-dir /path/to/artwork/images \
    --metadata /path/to/metadata.csv \
    --output-dir checkpoints \
    --batch-size 32 \
    --epochs 50 \
    --device cuda \
    --data-augmentation")

print("\nInference command example:")
print("python main.py \
    --input /path/to/query/image.jpg \
    --output-dir results \
    --database /path/to/metadata.csv \
    --data-dir /path/to/artwork/images \
    --mappings checkpoints/artist_mappings.json \
    --model checkpoints/model_final.pth \
    --top-k 5 \
    --visualize")
